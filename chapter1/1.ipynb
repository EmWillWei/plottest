# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /Users/will/.pyenv/versions/3.7.9/lib/python3.7/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
x = np.linspace(0.05, 10, 1000)
y = np.cos(x)

# %%
plt.plot(x,y, ls='-', lw=2, label="plot figure")
plt.legend()
plt.show()

# %%
y = np.random.rand(1000)

# %%
plt.scatter(x,y, label="scatter figure", color="r")
plt.legend()
plt.xlim(0.05, 10)
plt.ylim(0,1.2)
plt.show()

# %%
x = np.linspace(0.05, 10, 1000)
y = np.sin(x)
plt.plot(x,y, ls='-', lw=2, label="plot figure")
plt.legend()
plt.annotate("maximum", xy=(np.pi/2, 1.0), xytext=(np.pi/2+1.0, 0.8), arrowprops=dict(arrowstyle="->"))
plt.text(3.10, 0.09, "y=sin(x)")
plt.axvline(x=4.0, c="r", ls="--", lw=2)
plt.axhline(y=0.0, c="y", ls="--", lw=2)
plt.show()
